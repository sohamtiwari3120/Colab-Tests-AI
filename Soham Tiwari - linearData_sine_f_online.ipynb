# %% [markdown]
# # Function Approximation with a Linear Model
# $y=f(x)=\sin x$ <br />
# Approximate this function with a linear function of the form <br />
# $y = w_0 + w_1 x + w_2 x^2$ <br />
# in the range $x\in(0,2\pi)$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Generate data

# %%
def fx(x):
    '''
    Input:
        x: float (scalar) or np array
    Output:
        y: float (scalar) or np array; y=f(x)=sin(x)
        
    HINT: Use web search on how to take sine in numpy
    '''
    # YOUR CODE HERE
    y = np.sin(x)
    return y

# %%
'''Testing'''
def test_fx():
    assert fx(0)==0
    assert np.isclose(fx(np.pi/2), 1, atol=0.001)
    assert np.isclose(fx(np.pi/4), 0.707, atol=0.001)
    print('Test passed', '\U0001F44D')
test_fx()
# Out:
# Test passed 👍

# %%
def generateX_fx(N):
    '''
    Generate N random points in the range (0,1)
    Input:
        N: int
    Outputs:
        x: np vector of shape (N,)
        y: np vector of shape (N,); y=f(x)
    '''
    # YOUR CODE HERE
    x=np.random.random(N)*2*np.pi
    yd=fx(x)
    return x, yd

# %%
'''Testing'''
def test_generateX_fx():
    x, yd = generateX_fx(20)
    assert x.shape[0]==20
    assert yd.shape[0]==20
    print('Test passed', '\U0001F44D')
test_generateX_fx()
# Out:
# Test passed 👍

# %% [markdown]
# ### Plotting

# %%
def plotdata():
    x, yd = generateX_fx(20)
    import matplotlib.pyplot as plt
    i = x.argsort()
    plt.plot(x[i],yd[i])
    plt.ylabel('f(x)')
    plt.xlabel('x')
plotdata()

# %% [markdown]
# ## Training
# We will now define a linear model to estimate the above function, and train it with all the data

# %% [markdown]
# ### Define model
# $y = \sum_{d=0}^D w_d x^d$, here, $D$ is the degree of the model, say D=2 <br />
#
# In matrix representation: y = Aw <br/>

# %%
def createA(x, D):
    '''
    Create the matrix A with degree D
    Input:
        x: np vector of shape (N,)
        D: degree of the model
    Output:
        A: np matrix of shape (N,D+1)
    '''
    # YOUR CODE HERE
    A=[]
    for i in range(0,D+1):
      A+=[x**i]
    A=np.array(A)
    print("A = ",A," ", A.shape)
    return A

# %%
# '''Testing'''
# def test_createA():
#     x = np.array([1,2,3])
#     A = createA(x, 2)
#     assert A.shape==(3,3)
#     assert np.all(A[0,:]==1)
#     assert np.all(A==np.array([[1.0, 1.0, 1.0], [1.0, 2.0, 4.0], [1.0, 3.0, 9.0]]))
#     print('Test passed', '\U0001F44D')
# test_createA()

# %% [markdown]
# ### Estimate Weights
# Estimate w from yd and A. Use the least square solution you learnt in the video

# %%
def initialize_w(D):
    '''
    Inputs:
        A: np matrix of shape (N,D+1)
        yd: np vector of shape (N,)
    Output:
        w: np vector of shape (D+1,)
    '''
    # YOUR CODE HERE
    w=np.random.random(D+1)
    return w

# %%
# '''Testing'''
# def test_train_w():
#     A = np.array([[1.0, 1.0, 1.0], [1.0, 2.0, 4.0], [1.0, 3.0, 9.0]])
#     yd = np.array([1,2,3])
#     assert np.all(np.isclose(train_w(A, yd), np.array([0,1,0]), atol=.001))
#     yd = yd*yd
#     assert np.all(np.isclose(train_w(A, yd), np.array([0,0,1]), atol=.001))
#     print('Test passed', '\U0001F44D')
# test_train_w()

# %% [markdown]
# ### Estimate y from the model, given x

# %%
def predict_y(A,w):
    '''
    Inputs:
        w: np vector of shape (D+1,)
        x: np vector of shape (N,)
    Outputs:
        y: np vector of shape (N,); y=Aw
    '''
    # YOUR CODE HERE
    y=A.dot(w)
    print("y = ",y," ",y.shape)
    return y

# %%
# def test_predict_y():
#     w = np.array([1,2,3])
#     x = np.array([0.2,0.5,0.6])
#     y = predict_y(w, x)
#     assert np.all(np.isclose(y, np.array([1.52, 2.75, 3.28]), atol=0.001))
#     print('Test passed', '\U0001F44D')
# test_predict_y()

# %% [markdown]
# ### Estimate Error
# Find E as the mean squared error

# %%
def compute_e(yd, y):
    '''
    Inputs:
        y: np vector of shape (N,); y=Aw
        yd: np vector of shape (N,); yd=f(x), ie., desired or true value
    Output:
        mse: mean squared error
    '''
    # YOUR CODE HERE
    e=yd-y
    return e

# %%
# '''Testing'''
# def test_compute_mse():
#     yd = np.array([1,0,1,0])
#     y = np.array([.8,.2,.8,.2])
#     assert np.isclose(compute_mse(y, yd), 0.04, atol=0.003)
#     print('Test passed', '\U0001F44D')
# test_compute_mse()

# %% [markdown]
# ### Plotting

# %%
def plotModel(x, y, yd):
    import matplotlib.pyplot as plt
    i = x.argsort()
    plt.figure()
    plt.plot(x[i],y[i],'g-o')
    plt.plot(x[i],yd[i],'r-o')
    plt.ylabel('f(x)')
    plt.xlabel('x')
    plt.legend(['estimated', 'true'])

# %% [markdown]
# # EXPERIMENTS
# ## Could you train it?
# Using the above functions:
# - Generate 20 training points
# - Train your linear model using x and yd
# - Predict y (using the linear model you found above) for the training data x
# - Compare y with yd to find the mean-squared error

# %%
def trainModel(x, yd, D,eta):
  w=initialize_w(D)
  print("w0 = ",w," ",w.shape)
#   w=w.reshape(D+1,1)
  N=x.shape[0]
  E=[]
  for i in range(0,N):
    print(" ")
    print("x[",i,"] = ",x[i]," ",x[i].shape)
    print("yd[",i,"] =",yd[i]," ",yd[i].shape)
    a=createA(x[i],D)
    A=a.reshape(D+1,1)
    w=w.reshape(D+1,1)
    y=predict_y(A.T,w)
    y=y[0][0]
    e=yd[i]-y
    e=np.array(e)
    E+=[e**2]
    e=e.reshape(1,1)
    print("e =",e)
    w = w + eta *(A.dot(e))
  return w,E

# %%
x,yd=generateX_fx(20)
print("x = ",x," ",x.shape)
print(" ")
print("yd = ",yd," ",yd.shape)
print(" ")
eta=0.001
D=2
w,E=trainModel(x,yd,D,eta)
print(" ")
print(w)
print(" ")
print(E)
# Out:
# x =  [1.45619745 3.74783967 3.35582555 5.46639737 2.01280579 6.09701941
#  1.92441176 1.22369103 4.10058826 1.94340415 4.93895415 2.47417682
#  4.78094953 4.96733974 2.29631764 2.27692798 4.60769589 1.07182616
#  4.49047863 0.4946852 ]   (20,)
#
# yd =  [ 0.99344073 -0.5697873  -0.21259793 -0.72895073  0.90389393 -0.18509241
#   0.93812685  0.94036136 -0.81861511  0.93138115 -0.97444371  0.61895839
#  -0.99765065 -0.96767571  0.74815362  0.76087771 -0.99452468  0.87807582
#  -0.97547877  0.47475462]   (20,)
#
# w0 =  [0.92971527 0.85372964 0.59231524]   (3,)
#
# x[ 0 ] =  1.4561974480632607   ()
# yd[ 0 ] = 0.9934407317324196   ()
# A =  [1.         1.45619745 2.12051101]   (3,)
# y =  [[3.42892519]]   (1, 1)
# e = [[-2.43548446]]
#
# x[ 1 ] =  3.7478396666877773   ()
# yd[ 1 ] = -0.569787304657634   ()
# A =  [ 1.          3.74783967 14.04630217]   (3,)
# y =  [[12.36092687]]   (1, 1)
# e = [[-12.93071418]]
#
# x[ 2 ] =  3.3558255537203716   ()
# yd[ 2 ] = -0.21259792713854542   ()
# A =  [ 1.          3.35582555 11.26156515]   (3,)
# y =  [[8.17159741]]   (1, 1)
# e = [[-8.38419534]]
#
# x[ 3 ] =  5.466397367918557   ()
# yd[ 3 ] = -0.7289507258051059   ()
# A =  [ 1.          5.46639737 29.88150018]   (3,)
# y =  [[14.43090873]]   (1, 1)
# e = [[-15.15985946]]
#
# x[ 4 ] =  2.0128057933450143   ()
# yd[ 4 ] = 0.9038939260155544   ()
# A =  [1.         2.01280579 4.05138716]   (3,)
# y =  [[1.70620299]]   (1, 1)
# e = [[-0.80230906]]
#
# x[ 5 ] =  6.09701940742613   ()
# yd[ 5 ] = -0.18509241337939067   ()
# A =  [ 1.          6.09701941 37.17364565]   (3,)
# y =  [[-0.30417977]]   (1, 1)
# e = [[0.11908735]]
#
# x[ 6 ] =  1.9244117625406405   ()
# yd[ 6 ] = 0.9381268511178777   ()
# A =  [1.         1.92441176 3.70336063]   (3,)
# y =  [[1.69649476]]   (1, 1)
# e = [[-0.75836791]]
#
# x[ 7 ] =  1.2236910266970553   ()
# yd[ 7 ] = 0.9403613620765987   ()
# A =  [1.         1.22369103 1.49741973]   (3,)
# y =  [[1.51678941]]   (1, 1)
# e = [[-0.57642805]]
#
# x[ 8 ] =  4.100588256206148   ()
# yd[ 8 ] = -0.8186151132184026   ()
# A =  [ 1.          4.10058826 16.81482405]   (3,)
# y =  [[1.28068332]]   (1, 1)
# e = [[-2.09929843]]
#
# x[ 9 ] =  1.943404149907899   ()
# yd[ 9 ] = 0.9313811473366335   ()
# A =  [1.         1.94340415 3.77681969]   (3,)
# y =  [[1.52770195]]   (1, 1)
# e = [[-0.59632081]]
#
# x[ 10 ] =  4.938954148388304   ()
# yd[ 10 ] = -0.9744437142709901   ()
# A =  [ 1.          4.93895415 24.39326808]   (3,)
# y =  [[-0.20400905]]   (1, 1)
# e = [[-0.77043466]]
#
# x[ 11 ] =  2.4741768202547654   ()
# yd[ 11 ] = 0.6189583900252937   ()
# A =  [1.         2.47417682 6.12155094]   (3,)
# y =  [[1.32431726]]   (1, 1)
# e = [[-0.70535887]]
#
# x[ 12 ] =  4.78094953328793   ()
# yd[ 12 ] = -0.9976506457804305   ()
# A =  [ 1.          4.78094953 22.85747844]   (3,)
# y =  [[-0.58797087]]   (1, 1)
# e = [[-0.40967978]]
#
# x[ 13 ] =  4.967339743084206   ()
# yd[ 13 ] = -0.9676757143985925   ()
# A =  [ 1.          4.96733974 24.67446412]   (3,)
# y =  [[-1.07643041]]   (1, 1)
# e = [[0.1087547]]
#
# x[ 14 ] =  2.296317638637445   ()
# yd[ 14 ] = 0.7481536199139909   ()
# A =  [1.         2.29631764 5.2730747 ]   (3,)
# y =  [[1.30847678]]   (1, 1)
# e = [[-0.56032316]]
#
# x[ 15 ] =  2.2769279805948273   ()
# yd[ 15 ] = 0.7608777142977307   ()
# A =  [1.         2.27692798 5.18440103]   (3,)
# y =  [[1.29543514]]   (1, 1)
# e = [[-0.53455743]]
#
# x[ 16 ] =  4.607695885203599   ()
# yd[ 16 ] = -0.9945246817372531   ()
# A =  [ 1.          4.60769589 21.23086137]   (3,)
# y =  [[-0.65378655]]   (1, 1)
# e = [[-0.34073814]]
#
# x[ 17 ] =  1.0718261585504278   ()
# yd[ 17 ] = 0.8780758240856058   ()
# A =  [1.         1.07182616 1.14881131]   (3,)
# y =  [[1.33949545]]   (1, 1)
# e = [[-0.46141963]]
#
# x[ 18 ] =  4.49047862603548   ()
# yd[ 18 ] = -0.9754787729288438   ()
# A =  [ 1.          4.49047863 20.16439829]   (3,)
# y =  [[-0.66685718]]   (1, 1)
# e = [[-0.30862159]]
#
# x[ 19 ] =  0.49468520425450674   ()
# yd[ 19 ] = 0.47475461733254837   ()
# A =  [1.         0.4946852  0.24471345]   (3,)
# y =  [[1.15442184]]   (1, 1)
# e = [[-0.67966722]]
#
# [[ 0.88142933]
#  [ 0.66463504]
#  [-0.23161502]]
#
# [5.931584538053908, 167.20336910174285, 70.29473150408406, 229.82133885004097, 0.643699826566245, 0.014181797965675466, 0.5751218833813415, 0.33226929355641455, 4.407053896254619, 0.3555985051515301, 0.5935695696534198, 0.49753112848330455, 0.1678375209941835, 0.011827584464790788, 0.31396204280157375, 0.2857516430287345, 0.11610247678541744, 0.212908075063553, 0.09524728632113312, 0.46194752826259183]

# %%
# '''testing'''
# def test_trainModel():
#     N = 20
#     D = 2
#     x, y, yd, w, mse = trainModel(N,D)
#     assert x.shape[0]==20
#     assert w.shape[0]==D+1
#     print(w)
#     print('MSE on train data = ', mse)
# #     plotModel(x,y,yd)
#     print('Test passed', '\U0001F44D')
# test_trainModel()

# %% [markdown]
# ## Could you test it on new (test) points?
# Using the above functions:
# - Generate 30 test points
# - Estimate y using the linear model w you found above. Do NOT train again
# - Compare y with yd to find the mean-squared error <br />

# %%
# '''Testing'''
# def test_testModel():
#     N = 30
#     D = 10
#     x, y, yd, w, mse = trainModel(N,D)
#     assert x.shape[0]==N
#     assert w.shape[0]==D+1
#     print(w)
#     print('MSE on train data = ', mse)
#     plotModel(x,y,yd)
#     Ntest = 50
#     x, y, yd, mse = testModel(Ntest,w)
#     print('MSE on test data = ', mse)
#     plotModel(x,y,yd)
#     print('Test passed', '\U0001F44D')
# test_testModel()

# %% [markdown]
# # ADVANCED
#
# ## Does the performance improve with increasing the number of training points?
# - Repeat the training with different no. of samples. Take N=3, 5, 10, 30; and D=5
# - Plot training error vs N
# - Plot test error vs N

# %% [markdown]
# ## Does the performance improve with increasing the degree D of the model?
# - Repeat the training with different degree models. Take D=0, 1, 2, 4, 7, 12, and N=10
# - Plot training error vs D
# - Plot test error vs D
# - Plot y vs x for each D
