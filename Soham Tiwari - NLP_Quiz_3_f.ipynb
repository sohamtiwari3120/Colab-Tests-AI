# %% [markdown]
# ## 1)  Loading and cleaning raw dataset
# In [SLNI_dataset](https://raw.githubusercontent.com/Jivnesh/ISCLS-19/master/data/sample_snli.jsonl), each line containes one data-sample.

# %%
import json
import numpy as np
from tqdm import tqdm
# !wget https://raw.githubusercontent.com/Jivnesh/ISCLS-19/master/data/sample_snli.jsonl
# !ls
file_name='sample_snli.jsonl'
json_data = []
with open(file_name) as data_file:
  for l in data_file:
    json_data.append(json.loads(l))
print('Dataset loaded.')
# Out:
# --2019-06-23 04:50:13--  https://raw.githubusercontent.com/Jivnesh/ISCLS-19/master/data/sample_snli.jsonl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50743 (50K) [text/plain]
# Saving to: ‘sample_snli.jsonl.1’
#
# sample_snli.jsonl.1 100%[===================>]  49.55K  --.-KB/s    in 0.02s
#
# 2019-06-23 04:50:13 (2.01 MB/s) - ‘sample_snli.jsonl.1’ saved [50743/50743]
#
# sample_data  sample_snli.jsonl	sample_snli.jsonl.1
# Dataset loaded.

# %%
json_data[0]
# Out:
# {'annotator_labels': ['neutral',
#   'entailment',
#   'neutral',
#   'neutral',
#   'neutral'],
#  'captionID': '4705552913.jpg#2',
#  'gold_label': 'neutral',
#  'pairID': '4705552913.jpg#2r1n',
#  'sentence1': 'Two women are embracing while holding to go packages.',
#  'sentence1_binary_parse': '( ( Two women ) ( ( are ( embracing ( while ( holding ( to ( go packages ) ) ) ) ) ) . ) )',
#  'sentence1_parse': '(ROOT (S (NP (CD Two) (NNS women)) (VP (VBP are) (VP (VBG embracing) (SBAR (IN while) (S (NP (VBG holding)) (VP (TO to) (VP (VB go) (NP (NNS packages)))))))) (. .)))',
#  'sentence2': 'The sisters are hugging goodbye while holding to go packages after just eating lunch.',
#  'sentence2_binary_parse': '( ( The sisters ) ( ( are ( ( hugging goodbye ) ( while ( holding ( to ( ( go packages ) ( after ( just ( eating lunch ) ) ) ) ) ) ) ) ) . ) )',
#  'sentence2_parse': '(ROOT (S (NP (DT The) (NNS sisters)) (VP (VBP are) (VP (VBG hugging) (NP (UH goodbye)) (PP (IN while) (S (VP (VBG holding) (S (VP (TO to) (VP (VB go) (NP (NNS packages)) (PP (IN after) (S (ADVP (RB just)) (VP (VBG eating) (NP (NN lunch))))))))))))) (. .)))'}

# %%
print(json_data[0]['gold_label'])
print(json_data[0]['sentence1'])
print(json_data[0]['sentence2'])
# Out:
# neutral
# Two women are embracing while holding to go packages.
# The sisters are hugging goodbye while holding to go packages after just eating lunch.

# %%
for i in range(5):
    print(json_data[i]['gold_label'])
# Out:
# neutral
# entailment
# contradiction
# -
# neutral

# %% [markdown]
# ### Preprocessing started
#  First datapoint is printed above for your  better understanding of how data looks. <br>
#  Each data-sample has different attributes like annotator_labels, captionID, gold_label, pairID, sentence1, sentence2 etc. So we are interested in three attributes, namely, sentence1, sentence2 and gold_label.
# The 'gold_label' field contains the label ('entailment', 'neutral' or 'contradiction') for each data point. There are some data points that don't have the gold_label (their value for the gold label field is '-'). We will only use those examples which have a gold label. Your job is to extract these three attributes (sentence1, sentence2 and gold_label) and preprocess it. <br>
#  You need to complete obtain_data function. It has two parts.<br>
#
#
# 1.   Filter out data points without a gold label and extract each sentence pair into a triple and concatenate them altogether into a list. For example,   triple = (s1, s2, label).
# 2.  Build the set of tokens from collection of  all sentence pairs (sentence1 and sentence2 of each sample). For example, your set of tokens will look like { '2',
#  '9',
#  'A',
#  'An',
#  'Angeles',
#  'Asian-themed',
#  'At',
#  'Chinese',
#  'Doctors'}

# %%
def obtain_data(json_data):
    """
    Input:
        json_data: list (with each row of this list being a dictionary)
    
    Action:
    
        1. Ignore data points without a gold label
        2. Extract each sentence pair into a tuple of size 3 and concatenate them altogether into a list.
        
        i.e., for each item in json_data, store sentence1, sentence2 and gold_label values into 'example' list if gold_label != '-'
        
        example = (sentence1, sentence2, gold_label)
        append the 'example' tuple into list 'data' 
        data.append(example)
        
    Output:
        data: list of tuples of size 3
    """ 
    # YOUR CODE HERE
    data=[]
    for i in json_data:
      if(not(i["gold_label"]=='-')):
        data+=[(i["sentence1"],i["sentence2"],i["gold_label"])]
    return data
    
data = obtain_data(json_data)

# %%
'''test for obtain_data'''
print(data)
# Out:
# [('Two women are embracing while holding to go packages.', 'The sisters are hugging goodbye while holding to go packages after just eating lunch.', 'neutral'), ('Two women are embracing while holding to go packages.', 'Two woman are holding packages.', 'entailment'), ('Two women are embracing while holding to go packages.', 'The men are fighting outside a deli.', 'contradiction'), ('Two young children in blue jerseys, one with the number 9 and one with the number 2 are standing on wooden steps in a bathroom and washing their hands in a sink.', 'Two kids at a ballgame wash their hands.', 'neutral'), ('Two young children in blue jerseys, one with the number 9 and one with the number 2 are standing on wooden steps in a bathroom and washing their hands in a sink.', 'Two kids in jackets walk to school.', 'contradiction'), ('A man selling donuts to a customer during a world exhibition event held in the city of Angeles', 'A woman drinks her coffee in a small cafe.', 'contradiction'), ('A man selling donuts to a customer during a world exhibition event held in the city of Angeles', 'A man selling donuts to a customer during a world exhibition event while people wait in line behind him.', 'neutral'), ('A man selling donuts to a customer during a world exhibition event held in the city of Angeles', 'A man selling donuts to a customer.', 'entailment'), ('Two young boys of opposing teams play football, while wearing full protection uniforms and helmets.', 'boys play football', 'entailment'), ('Two young boys of opposing teams play football, while wearing full protection uniforms and helmets.', 'boys scoring a touchdown', 'neutral'), ('A man in a blue shirt standing in front of a garage-like structure painted with geometric designs.', 'A man is repainting a garage', 'neutral'), ('A man in a blue shirt standing in front of a garage-like structure painted with geometric designs.', 'A man is wearing a blue shirt', 'entailment'), ('A man in a blue shirt standing in front of a garage-like structure painted with geometric designs.', 'A man is wearing a black shirt', 'contradiction'), ('Under a blue sky with white clouds, a child reaches up to touch the propeller of a plane standing parked on a field of grass.', 'A child is reaching to touch the propeller of a plane.', 'entailment'), ('Under a blue sky with white clouds, a child reaches up to touch the propeller of a plane standing parked on a field of grass.', 'A child is reaching to touch the propeller out of curiosity.', 'neutral'), ('Under a blue sky with white clouds, a child reaches up to touch the propeller of a plane standing parked on a field of grass.', 'A child is playing with a ball.', 'contradiction'), ('A woman is doing a cartwheel while wearing a bikini in the sand next to the beach.', 'A woman is fixing her home.', 'contradiction'), ('A woman is doing a cartwheel while wearing a bikini in the sand next to the beach.', 'A woman is doing a cartwheel and falls on her head.', 'contradiction'), ('Two men on bicycles competing in a race.', 'People are riding bikes.', 'entailment'), ('Two men on bicycles competing in a race.', 'Men are riding bicycles on the street.', 'neutral'), ('A young boy in a field of flowers carrying a ball', 'boy leaving baseball game', 'neutral'), ('A young boy in a field of flowers carrying a ball', 'dog in pool', 'contradiction'), ('Families waiting in line at an amusement park for their turn to ride.', 'The restaurant is very bad.', 'contradiction'), ('Families waiting in line at an amusement park for their turn to ride.', 'People are waiting in line at a restaurant.', 'contradiction'), ('Families waiting in line at an amusement park for their turn to ride.', 'People are waiting to see a movie.', 'contradiction'), ('A senior is waiting at the window of a restaurant that serves sandwiches.', 'A person waits to be served his food.', 'entailment'), ('A senior is waiting at the window of a restaurant that serves sandwiches.', 'A man is waiting in line for the bus ...

# %%
def tokens(json_data):
    """
    Input:
        json_data: list (with each row of this list being a dictionary)
       
    Output: 
        voc_set: list, list of unique words in json_data (only consider those elements of json_data for which gold_label is not '-')
    """
    # YOUR CODE HERE
    li=[]
    for i in json_data:
      if( not(i["gold_label"]=='-')):
        li+=[i["sentence1"].split()]
        li+=[i["sentence2"].split()]
#     print(li)
    li2=[]
    for i in li:
      li2+=i
    for i in range(len(li2)):
      li2[i]=li2[i].replace('.','')
    print(li2)
    li2=np.unique(np.array(li2))
    return li2
voc_set = tokens(json_data)
# Out:
# ['Two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', 'The', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', 'Two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', 'Two', 'woman', 'are', 'holding', 'packages', 'Two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', 'The', 'men', 'are', 'fighting', 'outside', 'a', 'deli', 'Two', 'young', 'children', 'in', 'blue', 'jerseys,', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', 'hands', 'in', 'a', 'sink', 'Two', 'kids', 'at', 'a', 'ballgame', 'wash', 'their', 'hands', 'Two', 'young', 'children', 'in', 'blue', 'jerseys,', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', 'hands', 'in', 'a', 'sink', 'Two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', 'A', 'man', 'selling', 'donuts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'Angeles', 'A', 'woman', 'drinks', 'her', 'coffee', 'in', 'a', 'small', 'cafe', 'A', 'man', 'selling', 'donuts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'Angeles', 'A', 'man', 'selling', 'donuts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', 'behind', 'him', 'A', 'man', 'selling', 'donuts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'Angeles', 'A', 'man', 'selling', 'donuts', 'to', 'a', 'customer', 'Two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football,', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', 'boys', 'play', 'football', 'Two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football,', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', 'boys', 'scoring', 'a', 'touchdown', 'A', 'man', 'in', 'a', 'blue', 'shirt', 'standing', 'in', 'front', 'of', 'a', 'garage-like', 'structure', 'painted', 'with', 'geometric', 'designs', 'A', 'man', 'is', 'repainting', 'a', 'garage', 'A', 'man', 'in', 'a', 'blue', 'shirt', 'standing', 'in', 'front', 'of', 'a', 'garage-like', 'structure', 'painted', 'with', 'geometric', 'designs', 'A', 'man', 'is', 'wearing', 'a', 'blue', 'shirt', 'A', 'man', 'in', 'a', 'blue', 'shirt', 'standing', 'in', 'front', 'of', 'a', 'garage-like', 'structure', 'painted', 'with', 'geometric', 'designs', 'A', 'man', 'is', 'wearing', 'a', 'black', 'shirt', 'Under', 'a', 'blue', 'sky', 'with', 'white', 'clouds,', 'a', 'child', 'reaches', 'up', 'to', 'touch', 'the', 'propeller', 'of', 'a', 'plane', 'standing', 'parked', 'on', 'a', 'field', 'of', 'grass', 'A', 'child', 'is', 'reaching', 'to', 'touch', 'the', 'propeller', 'of', 'a', 'plane', 'Under', 'a', 'blue', 'sky', 'with', 'white', 'clouds,', 'a', 'child', 'reaches', 'up', 'to', 'touch', 'the', 'propeller', 'of', 'a', 'plane', 'standing', 'parked', 'on', 'a', 'field', 'of', 'grass', 'A', 'child', 'is', 'reaching', 'to', 'touch', 'the', 'propeller', 'out', 'of', 'curiosity', 'Under', 'a', 'blue', 'sky', 'with', 'white', 'clouds,', 'a', 'child', 'reaches', 'up', 'to', 'touch', 'the', 'propeller', 'of', 'a', 'plane', 'standing', 'parked', 'on', 'a', 'field', 'of', 'grass', 'A', 'child', 'is', 'playing', 'with', 'a', 'ball', 'A', 'woman', 'is', 'doing', 'a', 'cartwheel', 'while', 'wearing', 'a', 'bikini', 'in', 'the', 'sand', 'next', 'to', 'the', 'beach', 'A', 'woman', 'is', 'fixing', 'her', 'home', 'A', 'woman', 'is', 'doing', 'a', 'cartwheel', 'while', 'wearing', 'a', 'bikini', 'in', 'the', 'sand', 'next', 'to', 'the', 'beach', 'A', 'woman', 'is', 'doing', 'a', 'cartwheel', 'and', 'falls', 'on',  ...

# %%
'''test for tokens'''
print(voc_set)
# Out:
# ['2' '9' 'A' 'An' 'Angeles' 'Asian-themed' 'At' 'Chinese' 'Doctors'
#  'Families' 'Kids' 'Man' 'Men' 'Nobody' 'People' 'The' 'Three' 'Two'
#  'Under' 'Women' 'a' 'after' 'amusement' 'an' 'and' 'animal' 'are' 'area,'
#  'as' 'at' 'bad' 'ball' 'ballgame' 'bar' 'baseball' 'bathroom' 'be'
#  'beach' 'behind' 'bicycles' 'bikes' 'bikini' 'black' 'blue' 'bone'
#  'bowtie' 'boy' 'boys' 'broke' 'bus' 'cafe' 'camera' 'car' 'carrying'
#  'cartwheel' 'catch' 'celebrating' 'cheese' 'chihuahua' 'child' 'children'
#  'cigarettes' 'city' 'clouds,' 'coffee' 'competing' 'confronts'
#  'congregates' 'costume' 'crowd' 'curiosity' 'curly' 'customer' 'dancing'
#  'deli' 'designs' 'doctors' 'dog' 'doing' 'donuts' 'down' 'dragon'
#  'drinks' 'during' 'eating' 'embracing' 'event' 'exhibition' 'falls'
#  'favorite' 'field' 'fighting' 'fixing' 'flowers' 'food' 'football'
#  'football,' 'for' 'front' 'full' 'game' 'garage' 'garage-like'
#  'geometric' 'go' 'goodbye' 'grass' 'green' 'grilled' 'hair' 'hands' 'has'
#  'having' 'head' 'held' 'helmets' 'her' 'him' 'his' 'holding' 'home'
#  'hugging' 'in' 'instrument' 'is' 'jackets' 'jerseys,' 'jumping' 'jumps'
#  'just' 'kids' 'leaving' 'line' 'long' 'looking' 'lunch' 'man' 'men' 'mix'
#  'movie' 'next' 'number' 'object' 'of' 'on' 'one' 'opposing' 'order' 'out'
#  'outdoor' 'outside' 'packages' 'painted' 'park' 'parked' 'patient'
#  'people' 'perform' 'performing' 'person' 'plane' 'play' 'playing' 'pool'
#  'propeller' 'protection' 'race' 'reaches' 'reaching' 'red' 'repainting'
#  'rest' 'restaurant' 'ride' 'riding' 'road' 'sand' 'sandwich' 'sandwiches'
#  'school' 'scoring' 'see' 'selling' 'senior' 'served' 'serves' 'shirt'
#  'side' 'single' 'sink' 'sisters' 'sky' 'small' 'smoking' 'standing'
#  'steps' 'street' 'structure' 'suit' 'suit,' 'surgeons' 'surgery'
#  'surrounding' 'swimming' 'symphony' 'tall' 'teams' 'that' 'the' 'their'
#  'to' 'touch' 'touchdown' 'toy' 'turn' 'underwater' 'uniforms' 'up' 'very'
#  'wait' 'waiting' 'waits' 'walk' 'wash' 'washing' 'wearing' 'while'
#  'white' 'window' 'with' 'woman' 'women' 'wooden' 'world' 'yellow' 'young']

# %%
"hello" in voc_set
# Out:
# False

# %% [markdown]
# ## Build your vocabulary
# Implement following three functions:
#
#
# 1.  **make_wtoi_dict**, word-to-integer is a python dictionary which can be used to map a word into a unique id. For example, stoi('hello') # This will give you an integer id  whose word map  is '*hello*'.
# 2. **itow**, integer-to-word is a python dictionary which can be used to map a given id into the corresponding word. For example, itos(100) # This will give you the word whose id is 100.
# 3.   Numericalize your data in the **process_data** function, namely convert the sentences into a list of ids and the labels into label_ids. (Use the stoi function and  label_id in the cell below for mapping.). Your output for ['Two women are embracing while holding to go packages.',
#  'The sisters are hugging goodbye while holding to go packages after just eating lunch.',
#  'neutral'] should look like ([44, 39, 13, 192, 231, 102, 141, 246, 168],
#   [43, 133, 13, 151, 135, 231, 102, 141, 246, 71, 185, 170, 159, 178],
#   1)

# %%
def make_wtoi_dict(voc_set):
    """
    Input: 
        voc_set: list, list of unique words
        
    Output: 
         wtoi_dict: dictionary, keys are words in voc_set, values are unique integer ids for each word between 0 and len(voc_set)-1         
    """
    # YOUR CODE HER{}
    wtoi_dict={}
    for i in range(len(voc_set)):
#       print()
      wtoi_dict[voc_set[i]]=i
    return wtoi_dict
  
wtoi_dict = make_wtoi_dict(voc_set)

# %%
print(wtoi_dict)
# Out:
eons': 200, 'surgery': 201, 'surrounding': 202, 'swimming': 203, 'symphony': 204, 'tall': 205, 'teams': 206, 'that': 207, 'the': 208, 'their': 209, 'to': 210, 'touch': 211, 'touchdown': 212, 'toy': 213, 'turn': 214, 'underwater': 215, 'uniforms': 216, 'up': 217, 'very': 218, 'wait': 219, 'waiting': 220, 'waits': 221, 'walk': 222, 'wash': 223, 'washing': 224, 'wearing': 225, 'while': 226, 'white': 227, 'window': 228, 'with': 229, 'woman': 230, 'women': 231, 'wooden': 232, 'world': 233, 'yellow': 234, 'young': 235}

# %%
def make_itow_dict(wtoi_dict):
    """
      Maps unique integer ids to words
      Input: 
          wtoi_dict: dictionary, contains word to integer mappings

      Output:
          itow_dict : dictionary, for each key, value in wtoi_dict - itow_dict should have a corresponding value, key pair

    """
    # YOUR CODE HERE
    itow_dict={}
    words=list(wtoi_dict.keys())
    for i in words:
      itow_dict[wtoi_dict[i]]=i
    return itow_dict
  
itow_dict = make_itow_dict(wtoi_dict)

# %%
print(itow_dict)
# Out:
# {0: '2', 1: '9', 2: 'A', 3: 'An', 4: 'Angeles', 5: 'Asian-themed', 6: 'At', 7: 'Chinese', 8: 'Doctors', 9: 'Families', 10: 'Kids', 11: 'Man', 12: 'Men', 13: 'Nobody', 14: 'People', 15: 'The', 16: 'Three', 17: 'Two', 18: 'Under', 19: 'Women', 20: 'a', 21: 'after', 22: 'amusement', 23: 'an', 24: 'and', 25: 'animal', 26: 'are', 27: 'area,', 28: 'as', 29: 'at', 30: 'bad', 31: 'ball', 32: 'ballgame', 33: 'bar', 34: 'baseball', 35: 'bathroom', 36: 'be', 37: 'beach', 38: 'behind', 39: 'bicycles', 40: 'bikes', 41: 'bikini', 42: 'black', 43: 'blue', 44: 'bone', 45: 'bowtie', 46: 'boy', 47: 'boys', 48: 'broke', 49: 'bus', 50: 'cafe', 51: 'camera', 52: 'car', 53: 'carrying', 54: 'cartwheel', 55: 'catch', 56: 'celebrating', 57: 'cheese', 58: 'chihuahua', 59: 'child', 60: 'children', 61: 'cigarettes', 62: 'city', 63: 'clouds,', 64: 'coffee', 65: 'competing', 66: 'confronts', 67: 'congregates', 68: 'costume', 69: 'crowd', 70: 'curiosity', 71: 'curly', 72: 'customer', 73: 'dancing', 74: 'deli', 75: 'designs', 76: 'doctors', 77: 'dog', 78: 'doing', 79: 'donuts', 80: 'down', 81: 'dragon', 82: 'drinks', 83: 'during', 84: 'eating', 85: 'embracing', 86: 'event', 87: 'exhibition', 88: 'falls', 89: 'favorite', 90: 'field', 91: 'fighting', 92: 'fixing', 93: 'flowers', 94: 'food', 95: 'football', 96: 'football,', 97: 'for', 98: 'front', 99: 'full', 100: 'game', 101: 'garage', 102: 'garage-like', 103: 'geometric', 104: 'go', 105: 'goodbye', 106: 'grass', 107: 'green', 108: 'grilled', 109: 'hair', 110: 'hands', 111: 'has', 112: 'having', 113: 'head', 114: 'held', 115: 'helmets', 116: 'her', 117: 'him', 118: 'his', 119: 'holding', 120: 'home', 121: 'hugging', 122: 'in', 123: 'instrument', 124: 'is', 125: 'jackets', 126: 'jerseys,', 127: 'jumping', 128: 'jumps', 129: 'just', 130: 'kids', 131: 'leaving', 132: 'line', 133: 'long', 134: 'looking', 135: 'lunch', 136: 'man', 137: 'men', 138: 'mix', 139: 'movie', 140: 'next', 141: 'number', 142: 'object', 143: 'of', 144: 'on', 145: 'one', 146: 'opposing', 147: 'order', 148: 'out', 149: 'outdoor', 150: 'outside', 151: 'packages', 152: 'painted', 153: 'park', 154: 'parked', 155: 'patient', 156: 'people', 157: 'perform', 158: 'performing', 159: 'person', 160: 'plane', 161: 'play', 162: 'playing', 163: 'pool', 164: 'propeller', 165: 'protection', 166: 'race', 167: 'reaches', 168: 'reaching', 169: 'red', 170: 'repainting', 171: 'rest', 172: 'restaurant', 173: 'ride', 174: 'riding', 175: 'road', 176: 'sand', 177: 'sandwich', 178: 'sandwiches', 179: 'school', 180: 'scoring', 181: 'see', 182: 'selling', 183: 'senior', 184: 'served', 185: 'serves', 186: 'shirt', 187: 'side', 188: 'single', 189: 'sink', 190: 'sisters', 191: 'sky', 192: 'small', 193: 'smoking', 194: 'standing', 195: 'steps', 196: 'street', 197: 'structure', 198: 'suit', 199: 'suit,', 200: 'surgeons', 201: 'surgery', 202: 'surrounding', 203: 'swimming', 204: 'symphony', 205: 'tall', 206: 'teams', 207: 'that', 208: 'the', 209: 'their', 210: 'to', 211: 'touch', 212: 'touchdown', 213: 'toy', 214: 'turn', 215: 'underwater', 216: 'uniforms', 217: 'up', 218: 'very', 219: 'wait', 220: 'waiting', 221: 'waits', 222: 'walk', 223: 'wash', 224: 'washing', 225: 'wearing', 226: 'while', 227: 'white', 228: 'window', 229: 'with', 230: 'woman', 231: 'women', 232: 'wooden', 233: 'world', 234: 'yellow', 235: 'young'}

# %%
def wtoi(word, wtoi_dict):
  """
  Inputs:
    word: string, word for which id is required
    wtoi_dict: dictionary, contains word to int mappings
  Outputs:
    id : int, id corresponding to word from wtoi_dict if word is present in wtoi_dict.
         If word is not present in wtoi_dict, id = <unk-0>
  """
  # YOUR CODE HERE
  id="<unk-0>"
  if word in list(wtoi_dict.keys()):
    id=wtoi_dict[word]
  return id

# %%
print(wtoi("t",wtoi_dict))
# Out:
# <unk-0>

# %%
def itow(id, itow_dict):
  """
  Inputs:
    id: int, integer id for which word is required
    itow_dict: dictionary, contains integer to word mappings
  Outputs:
    word: string, word corresponding to id from itow_dict, if id is present in itow_dict.
          If id is not present in itow_dict, word = <OOV>
  """
  # YOUR CODE HERE
  word="<OOV>"
  if(id in list(itow_dict.keys())):
    word=itow_dict[id]
  return word

# %%
print(itow(600,itow_dict))
# Out:
# <OOV>

# %% [markdown]
# Numericalize your data in the **process_data** function, namely convert the sentences into a list of ids and the labels into label_ids. (Use the stoi function and  label_id in the cell below for mapping.). Your output for ['Two women are embracing while holding to go packages.',
#  'The sisters are hugging goodbye while holding to go packages after just eating lunch.',
#  'neutral'] may look like ([44, 39, 13, 192, 231, 102, 141, 246, 168],
#   [43, 133, 13, 151, 135, 231, 102, 141, 246, 71, 185, 170, 159, 178],
#   1) depending on your mappings

# %%
label_id = {'entailment': 0, 'neutral': 1, 'contradiction': 2}

def process_data(data, label_id):
    """
    Input:
        data: list, a list of 3-sized tuples
        label_id: a dictionary of length 3 (as defined above)
        
    Output:
        numerialized_data: list, list of 3-sized tuples
        
    Action:
        1. Convert each sentence pair into a tuple of size 3, (token_id_list, token_id_list, int) and concatenate them altogether into a list.   
        2. Out-of-vocabulary tokens should be mapped to '<unk-0>'.
        
        i.e., 
        
        data = [sentence1, sentence2, gold_label] is given
        a. Now for each word in sentence1, find unique integer id corresponding to that word using wtoi(word)
        b. append all the integers obtained into a list (say n_s1)
        c. do same thing for sentence2 and store it in n_s2
        d. Now using label_id, store integer value corresponding to gold_label in n_y 
        e. append n_s1, n_s2 and n_y in a list 'numerialized_data'
        f. return numerialized_data
    """
    # YOUR CODE HERE
    li=[]
    for i in data:
      temp1=[]
      temp2=[]
      word1=i[0].replace('.','').split()
      word2=i[1].replace('.','').split()
#       print(word1)
      for j in word1:
#         print(j)
        temp1+=[wtoi(j,wtoi_dict)]
      for j in word2:
        temp2+=[wtoi(j,wtoi_dict)]
      temp3=label_id[i[2]]
      li+=[(temp1,temp2,temp3)]
    return li
numerialized_data = process_data(data, label_id)

# %%
print(numerialized_data)
# Out:
# [([17, 231, 26, 85, 226, 119, 210, 104, 151], [15, 190, 26, 121, 105, 226, 119, 210, 104, 151, 21, 129, 84, 135], 1), ([17, 231, 26, 85, 226, 119, 210, 104, 151], [17, 230, 26, 119, 151], 0), ([17, 231, 26, 85, 226, 119, 210, 104, 151], [15, 137, 26, 91, 150, 20, 74], 2), ([17, 235, 60, 122, 43, 126, 145, 229, 208, 141, 1, 24, 145, 229, 208, 141, 0, 26, 194, 144, 232, 195, 122, 20, 35, 24, 224, 209, 110, 122, 20, 189], [17, 130, 29, 20, 32, 223, 209, 110], 1), ([17, 235, 60, 122, 43, 126, 145, 229, 208, 141, 1, 24, 145, 229, 208, 141, 0, 26, 194, 144, 232, 195, 122, 20, 35, 24, 224, 209, 110, 122, 20, 189], [17, 130, 122, 125, 222, 210, 179], 2), ([2, 136, 182, 79, 210, 20, 72, 83, 20, 233, 87, 86, 114, 122, 208, 62, 143, 4], [2, 230, 82, 116, 64, 122, 20, 192, 50], 2), ([2, 136, 182, 79, 210, 20, 72, 83, 20, 233, 87, 86, 114, 122, 208, 62, 143, 4], [2, 136, 182, 79, 210, 20, 72, 83, 20, 233, 87, 86, 226, 156, 219, 122, 132, 38, 117], 1), ([2, 136, 182, 79, 210, 20, 72, 83, 20, 233, 87, 86, 114, 122, 208, 62, 143, 4], [2, 136, 182, 79, 210, 20, 72], 0), ([17, 235, 47, 143, 146, 206, 161, 96, 226, 225, 99, 165, 216, 24, 115], [47, 161, 95], 0), ([17, 235, 47, 143, 146, 206, 161, 96, 226, 225, 99, 165, 216, 24, 115], [47, 180, 20, 212], 1), ([2, 136, 122, 20, 43, 186, 194, 122, 98, 143, 20, 102, 197, 152, 229, 103, 75], [2, 136, 124, 170, 20, 101], 1), ([2, 136, 122, 20, 43, 186, 194, 122, 98, 143, 20, 102, 197, 152, 229, 103, 75], [2, 136, 124, 225, 20, 43, 186], 0), ([2, 136, 122, 20, 43, 186, 194, 122, 98, 143, 20, 102, 197, 